# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataframe = pd.read_csv('LoanExport.csv')
# Out:
# <ipython-input-57-70b4c8c767c0>:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframe = pd.read_csv('LoanExport.csv')

# %%
dataframe
# Out:
#         CreditScore  FirstPaymentDate FirstTimeHomebuyer  MaturityDate    MSA  \
# 0                 0            199902                  N        202901  16974
# 1                 0            199902                  N        202901  19740
# 2                 0            199902                  N        202901  29940
# 3                 0            199902                  N        202901  31084
# 4                 0            199902                  N        202901  35644
# ...             ...               ...                ...           ...    ...
# 148938          719            199903                  Y        202902  X
# 148939          719            199903                  Y        202902  X
# 148940          719            199903                  Y        202902  X
# 148941          719            199903                  Y        202902  X
# 148942          719            199903                  Y        202902  X
#
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148943 entries, 0 to 148942
# Data columns (total 28 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   CreditScore         148943 non-null  int64
#  1   FirstPaymentDate    148943 non-null  int64
#  2   FirstTimeHomebuyer  148943 non-null  object
#  3   MaturityDate        148943 non-null  int64
#  4   MSA                 148943 non-null  object
#  5   MIP                 148943 non-null  int64
#  6   Units               148943 non-null  int64
#  7   Occupancy           148943 non-null  object
#  8   OCLTV               148943 non-null  int64
#  9   DTI                 148943 non-null  int64
#  10  OrigUPB             148943 non-null  int64
#  11  LTV                 148943 non-null  int64
#  12  OrigInterestRate    148943 non-null  float64
#  13  Channel             148943 non-null  object
#  14  PPM                 148943 non-null  object
# ...

# %%
dataframe.isna().sum()
# Out:
# CreditScore               0
# FirstPaymentDate          0
# FirstTimeHomebuyer        0
# MaturityDate              0
# MSA                       0
# MIP                       0
# Units                     0
# Occupancy                 0
# OCLTV                     0
# DTI                       0
# OrigUPB                   0
# LTV                       0
# OrigInterestRate          0
# Channel                   0
# PPM                       0
# ProductType               0
# PropertyState             0
# PropertyType              0
# PostalCode                0
# LoanSeqNum                0
# LoanPurpose               1
# OrigLoanTerm              1
# NumBorrowers              1
# SellerName            12665
# ServicerName              1
# EverDelinquent            1
# MonthsDelinquent          1
# MonthsInRepayment         1
# dtype: int64

# %%
# handling missing values in the original dataframe
clean_dataframe = dataframe.dropna()
clean_dataframe.head()
# Out:
#    CreditScore  FirstPaymentDate FirstTimeHomebuyer  MaturityDate    MSA  MIP  \
# 0            0            199902                  N        202901  16974   25
# 1            0            199902                  N        202901  19740    0
# 2            0            199902                  N        202901  29940    0
# 3            0            199902                  N        202901  31084    0
# 4            0            199902                  N        202901  35644    0
#
#    Units Occupancy  OCLTV  DTI  ...  PostalCode    LoanSeqNum  LoanPurpose  \
# 0      1         O     89   27  ...       60400  F199Q1268030            P
# 1      1         O     73   17  ...       80200  F199Q1015092            N
# 2      1         O     75   16  ...       66000  F199Q1266886            N
# 3      1         O     76   14  ...       90700  F199Q1178167            N
# 4      1         O     78   18  ...        7600  F199Q1178517            N
#
# ...

# %%
clean_dataframe['NumBorrowers'].value_counts()
# Out:
# NumBorrowers
# 2     89787
# 1     46328
# X       163
# Name: count, dtype: int64

# %%
clean_dataframe['FirstTimeHomebuyer'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='FirstTimeHomebuyer'>

# %%
plt.scatter(data = clean_dataframe,x ='MSA' ,y ='MIP', color = 'gold' )
plt.title('Corelation between MIP and MSA')
# Out:
# Text(0.5, 1.0, 'Corelation between MIP and MSA')

# %%
clean_dataframe = clean_dataframe.drop(['PostalCode','LoanSeqNum'], axis = 1)

# %%
clean_dataframe['ServicerName'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='ServicerName'>

# %%
clean_dataframe.head()
# Out:
#    CreditScore  FirstPaymentDate FirstTimeHomebuyer  MaturityDate    MSA  MIP  \
# 0            0            199902                  N        202901  16974   25
# 1            0            199902                  N        202901  19740    0
# 2            0            199902                  N        202901  29940    0
# 3            0            199902                  N        202901  31084    0
# 4            0            199902                  N        202901  35644    0
#
#    Units Occupancy  OCLTV  DTI  ...  PropertyState  PropertyType  LoanPurpose  \
# 0      1         O     89   27  ...             IL            SF            P
# 1      1         O     73   17  ...             CO            SF            N
# 2      1         O     75   16  ...             KS            SF            N
# 3      1         O     76   14  ...             CA            SF            N
# 4      1         O     78   18  ...             NJ            SF            N
#
# ...

# %%
clean_dataframe['Occupancy'].value_counts()
# Out:
# Occupancy
# O    130542
# I      3441
# S      2295
# Name: count, dtype: int64

# %%
clean_dataframe['NumBorrowers'].describe()
# Out:
# count    136115.000000
# mean          1.659641
# std           0.473832
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           2.000000
# max           2.000000
# Name: NumBorrowers, dtype: float64

# %%
numerical_data = clean_dataframe[['CreditScore','FirstPaymentDate','MaturityDate','Units','OrigLoanTerm','NumBorrowers']]
numerical_data.corr()
# Out:
#                   CreditScore  FirstPaymentDate  MaturityDate     Units  \
# CreditScore          1.000000         -0.002411      0.010335 -0.007504
# FirstPaymentDate    -0.002411          1.000000      0.214148 -0.001575
# MaturityDate         0.010335          0.214148      1.000000  0.003408
# Units               -0.007504         -0.001575      0.003408  1.000000
# OrigLoanTerm         0.010689         -0.522754      0.703287  0.004126
# NumBorrowers         0.045502          0.009118     -0.007136 -0.021344
#
#                   OrigLoanTerm  NumBorrowers
# CreditScore           0.010689      0.045502
# FirstPaymentDate     -0.522754      0.009118
# MaturityDate          0.703287     -0.007136
# Units                 0.004126     -0.021344
# OrigLoanTerm          1.000000     -0.012484
# NumBorrowers         -0.012484      1.000000

# %%
# Step 1: Replace 'X' with the specified value
clean_dataframe['NumBorrowers'].replace('X', 1, inplace=True)

# Convert the column to numeric if needed
clean_dataframe['NumBorrowers'] = pd.to_numeric(clean_dataframe['NumBorrowers'], errors='coerce')

clean_dataframe['NumBorrowers'].value_counts()
# Out:
# NumBorrowers
# 2.0    89787
# 1.0    46328
# Name: count, dtype: int64

# %%
clean_dataframe['PropertyType'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='PropertyType'>

# %%
clean_dataframe['Channel'].value_counts()
# Out:
# Channel
# T    80883
# R    55236
# C      107
# B       52
# Name: count, dtype: int64

# %%
df = pd.get_dummies(clean_dataframe)
df.head()
# Out:
#    CreditScore  FirstPaymentDate  MaturityDate  MIP  Units  OCLTV  DTI  \
# 0            0            199902        202901   25      1     89   27
# 1            0            199902        202901    0      1     73   17
# 2            0            199902        202901    0      1     75   16
# 3            0            199902        202901    0      1     76   14
# 4            0            199902        202901    0      1     78   18
#
#    OrigUPB  LTV  OrigInterestRate  ...  ServicerName_GMACMTGECORP          \
# 0   117000   89             6.750  ...                              False
# 1   109000   73             6.500  ...                              False
# 2    88000   75             6.875  ...                              False
# 3   160000   76             6.875  ...                               True
# 4   109000   78             7.125  ...                               True
#
#    ServicerName_HOMESIDELENDINGINC   ServicerName_JPMORGANCHASEBANKNA  \
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 136278 entries, 0 to 148941
# Data columns (total 26 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   CreditScore         136278 non-null  int64
#  1   FirstPaymentDate    136278 non-null  int64
#  2   FirstTimeHomebuyer  136278 non-null  object
#  3   MaturityDate        136278 non-null  int64
#  4   MSA                 136278 non-null  object
#  5   MIP                 136278 non-null  int64
#  6   Units               136278 non-null  int64
#  7   Occupancy           136278 non-null  object
#  8   OCLTV               136278 non-null  int64
#  9   DTI                 136278 non-null  int64
#  10  OrigUPB             136278 non-null  int64
#  11  LTV                 136278 non-null  int64
#  12  OrigInterestRate    136278 non-null  float64
#  13  Channel             136278 non-null  object
#  14  PPM                 136278 non-null  object
# ...
